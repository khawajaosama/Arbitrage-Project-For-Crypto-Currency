# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
url_link='https://www.cryptocompare.com/api/data/coinsnapshotfullbyid/?id={}'.format(str(3808))

# %%
whole_data=(requests.get(url_link)).json()#['Data']['General'] #WHOLE DATA ABOUT THE COINS

# %%
whole_data
# Out:
# {'Data': {'General': {'Algorithm': 'Scrypt',
#    'BaseAngularUrl': '/coins/ltc/',
#    'BlockNumber': 1382821,
#    'BlockReward': 25.0,
#    'BlockRewardReduction': '50%',
#    'BlockTime': 150,
#    'DangerTop': '',
#    'Description': '<p>Litecoin LTC - provides faster transaction confirmations (2.5 minutes on average) and uses a memory-hard, scrypt-based mining proof-of-work algorithm to target the regular computers and GPUs most people already have - which are its main differentials to Bitcoin. The Litecoin network is scheduled to produce 84 million currency units with a halving in reward every four years just like bitcoin. The coin was created by a Google employee, Charles Lee. Litecoin is in second spot to Bitcoin and has spawned numerous clones - however it has a solid base of support and dedicated development team.</p><p><span>The Litecoin project is currently maintained by a core group of 6 software developers, led by Charles Lee, with a large community that is growing in support.</span></p><p>In May 2017, Litecoin became the first of the Top 5 (By Market Cap) cryptocurrencies to implement the\xa0SegWit scaling solution. Later in May of the same year, the first Lightning Network transaction was completed through litecoin, transferring 0.00000001 LTC from Zurich to San Francisco in under one second.</p>',
#    'DifficultyAdjustment': '2016 blocks',
#    'DocumentType': 'Webpagecoinp',
#    'Features': '<p>Litecoin is an open source software project released under the MIT/X11 license which gives you the power to run, modify, and copy the software and to distribute, at your option, modified copies of the software. The software is released in a transparent process that allows for independent verification of binaries and their corresponding source code.</p><p>Miners are currently awarded with 25 new litecoins per block, an amount which gets halved roughly every 4 years (every 840,000 blocks).\xa0The Litecoin network is therefore scheduled to produce 84 million litecoins, which is 4 times as many currency units as Bitcoin.</p><p>The Litecoin blockchain is capable of handling higher transaction volume than its counterpart - Bitcoin. Due to more frequent block generation, the network supports more transactions without a need to modify the software in the future.\xa0As a result, merchants get faster confirmation times, while still having ability to wait for more confirmations when selling bigger ticket items.</p>',
#    'H1Text': 'Litecoin (LTC)',
#    'Id': '3808',
#    'ImageUrl': '/media/19782/litecoin-logo.png',
#    'InfoTop': '',
#    'LastBlockExplorerUpdateTS': 1520702819,
#    'Name': 'Litecoin',
#    'NetHashesPerSecond': 177675622512430.8,
#    'PreviousTotalCoinsMined': 55567917.7471042,
#    'ProofType': 'PoW',
#    'Sponsor': {'ImageUrl': '/media/27010752/cryptoinvestorshow_logo_centre_100x65.jpg',
#     'Link': 'https://www.cryptoinvestor.show/?utm_source=cryptocompare&utm_medium=email&utm_campaign=cryptocompare_email',
#     'TextTop': 'Join us at'},
#    'StartDate': '13/10/2011',
#    'Symbol': 'LTC',
#    'Technology': '<p>- Faster transaction confirmations (2.5 minutes on average)</p><p>- Scrypt-based mining proof-of-work algorithm</p><p>- 84 million litecoins</p><p>- Higher transaction volume than Bitcoin</p><p>-\xa0MIT/X11 license</p><p>\xa0</p>',
#    'TotalCoinSupply': '84000000',
#    'TotalCoinsMined': 55567942.7471042,
#    'Twitter': '@litecoin',
#    'Url': '/coins/ltc/',
#    'WarningTop': '',
#    'Website': "<a href='https://litecoin.com' target='_blank'>Litecoin</a>",
#    '2~LiveCoin~LTC~USD',
#    '2~Cryptopia~LTC~BTC',
#    '2~BTCE~LTC~USD',
#    '2~CCEX~LTC~BTC',
#    '2~BXinth~LTC~THB',
#    '2~BitTrex~LTC~BTC',
#    '2~Poloniex~LTC~XMR',
#    '2~TradeSatoshi~LTC~USDT',
#    '2~Cryptsy~LTC~XRP',
#    '2~BitZ~LTC~BTC',
#    '2~CCEX~LTC~DOGE',
#    '2~Yobit~LTC~DOGE',
#    '2~Binance~LTC~USDT',
#    '2~BitSquare~LTC~BTC',
#    '2~BXinth~LTC~BTC',
#    '2~BTC38~LTC~BTC',
#    '2~Kraken~LTC~USD',
#    '2~Bitstamp~LTC~BTC',
#    '2~WavesDEX~LTC~WGR',
#    '2~Cexio~LTC~BTC',
#    '2~Cryptopia~LTC~NZDT',
#    '2~WavesDEX~LTC~OCL',
#    '2~Bitstamp~LTC~USD',
#    '2~WavesDEX~LTC~EOT',
#    '2~Bitfinex~LTC~USD',
#    '2~Poloniex~LTC~BTC',
#    '2~WavesDEX~LTC~ZEC',
#    '2~Tidex~LTC~WUSD',
#    '2~BitTrex~LTC~USD',
#    '2~Abucoins~LTC~BTC',
#    '2~WavesDEX~LTC~ETH',
#    '2~BitFlip~LTC~RUB',
#    '2~BitSquare~LTC~DASH',
#    '2~Exmo~LTC~RUB',
#    '2~BitFlip~LTC~USD',
#    '2~WavesDEX~LTC~BCH',
#    '2~TrustDEX~LTC~BTC',
#    '2~LiveCoin~LTC~BTC',
#    '2~WavesDEX~LTC~RBX',
#    '2~Kraken~LTC~BTC',
#    '2~BitMarket~LTC~BTC',
#    '2~BitGrail~LTC~BTC',
#    '2~Jubi~LTC~CNY',
#    '2~OKEX~LTC~BTC',
#    '2~Cryptsy~LTC~BTC',
#    '2~Coinse~LTC~BTC',
#    '2~Coinbase~LTC~EUR',
#    '2~Bleutrade~LTC~DOGE',
#    '2~Gateio~LTC~BTC',
#    '2~CCEDK~LTC~DKK',
#    '2~Coinone~LTC~KRW',
#    '2~Gatecoin~LTC~EUR',
#    '2~WavesDEX~LTC~WNET',
#    '2~WavesDEX~LTC~WDESK',
#    '2~CryptoX~LTC~BTC',
#    '2~BitBay~LTC~PLN',
#    '2~Bleutrade~LTC~BTC',
#    '2~BTCE~LTC~CNH',
#    '2~WavesDEX~LTC~WTRY',
#    '2~Coinroom~LTC~PLN',
#    '2~TheRockTrading~LTC~BTC',
#    '2~WavesDEX~LTC~P2P',
#    '2~Cryptopia~LTC~ETH',
#    '2~Exmo~LTC~EUR',
#    '2~WavesDEX~LTC~WCASH',
#    '2~OKEX~LTC~USDT',
#    '2~Yobit~LTC~WAVES',
#    '2~Bleutrade~LTC~ETH',
#    '2~BTER~LTC~CNY',
#    '2~Bitso~LTC~MXN',
#    '2~Gatecoin~LTC~ETH',
#    '2~WavesDEX~LTC~EUR',
#    '2~TradeSatoshi~LTC~BCH',
#    '2~TrustDEX~LTC~AIC',
#    '2~TrustDEX~LTC~USDT',
#    '2~Yacuna~LTC~EUR',
#    '2~TrustDEX~LTC~VND',
#    '2~WavesDEX~LTC~SXAS',
#    '2~BitSquare~LTC~EUR',
#    '2~QuadrigaCX~LTC~BTC',
#    '2~Bitso~LTC~BTC',
#    '2~WavesDEX~LTC~WCT',
#    '2~CCEDK~LTC~EUR',
#    '2~Exmo~LTC~USD',
#    '2~Yacuna~LTC~BTC',
#    '2~OKCoin~LTC~CNY',
#    '2~HitBTC~LTC~EUR',
#    '2~BitFlip~LTC~EUR',
#    '2~BTCChina~LTC~CNY',
#    '2~Yobit~LTC~RUR',
#    '2~TradeSatoshi~LTC~BTC',
#    '2~Binance~LTC~BNB',
#    '2~Kucoin~LTC~USDT',
#    '2~WavesDEX~LTC~AKCHE',
#    '2~CCEDK~LTC~USD',
#    '2~Novaexchange~LTC~BTC',
#    '2~HuobiPro~LTC~USDT',
#    '2~Yobit~LTC~ETH',
#    '2~EXX~LTC~USDT',
#    '2~Huobi~LTC~CNY',
#    '2~QuadrigaCX~LTC~CAD',
#    '2~HitBTC~LTC~BTC',
#    '2~MercadoBitcoin~LTC~BRL',
#    '2~Liqui~LTC~USDT',
#    '2~BTCE~LTC~GBP',
#    '2~BTCE~LTC~BTC',
#    '2~BTCChina~LTC~BTC',
#    '2~Poloniex~LTC~USD',
#    '2~Gatecoin~LTC~BTC',
#    '2~Liqui~LTC~ETH',
#    '2~BitBay~LTC~BTC',
#    '2~OKEX~LTC~BCH',
#    '2~Tidex~LTC~WAVES',
#    '2~OKEX~LTC~ETH',
#    '2~Tidex~LTC~BTC',
#    '2~Bit2C~LTC~BTC',
#    '2~Liqui~LTC~BTC',
#    '2~BitBay~LTC~USD',
#    '2~EXX~LTC~BTC',
#    '2~HitBTC~LTC~ETH',
#    '2~BTCMarkets~LTC~BTC',
#    '2~Kucoin~LTC~NEO',
#    '2~WavesDEX~LTC~TKS',
#    '2~TheRockTrading~LTC~USD',
#    '2~OKCoin~LTC~USD',
#    '2~TradeSatoshi~LTC~DOGE',
#    '2~BTC38~LTC~CNY',
#    '2~WavesDEX~LTC~OCTANOX',
#    '2~WavesDEX~LTC~LIQUID',
#    '2~BitFlip~LTC~UAH',
#    '2~Gateio~LTC~USDT',
#    '2~Kucoin~LTC~ETH',
#    '2~Novaexchange~LTC~ETH',
#    '2~CCEDK~LTC~BTC',
#    '2~WavesDEX~LTC~B@',
#    '2~BTCMarkets~LTC~AUD',
#    '2~TuxExchange~LTC~BTC',
#    '2~Coinbase~LTC~USD',
#    '2~Coinroom~LTC~USD',
#    '2~WavesDEX~LTC~EQUA',
#    '2~Yobit~LTC~USD',
#    '2~CCEX~LTC~USD',
#    '2~HitBTC~LTC~USD',
#    '2~CCEDK~LTC~GBP',
#    '2~Yobit~LTC~BTC',
#    '2~Binance~LTC~ETH',
#    '2~HuobiPro~LTC~BTC',
#    '2~BitTrex~LTC~ETH',
#    '2~Exmo~LTC~BTC',
#    '2~Gatecoin~LTC~HKD',
#    '2~Gatecoin~LTC~USD',
#    '2~Cryptsy~LTC~USD',
#    '2~CCEX~LTC~ETH',
#    '2~Bitstamp~LTC~EUR',
#    '2~Bit2C~LTC~ILS',
#    '2~Bitfinex~LTC~BTC',
#    '2~Tidex~LTC~WEUR',
#    '2~LakeBTC~LTC~BTC',
#    '2~Kucoin~LTC~BTC',
#    '2~Cexio~LTC~EUR',
#    '2~WavesDEX~LTC~WGO',
#    '2~Kraken~LTC~EUR',
#    '2~BTER~LTC~BTC',
#    '2~Binance~LTC~BTC',
#    '2~Bithumb~LTC~KRW',
#    '2~BTCE~LTC~RUB',
#    '2~Tidex~LTC~ETH',
#    '2~TheRockTrading~LTC~EUR',
#    '2~Tidex~LTC~USDT',
#    '2~Coinbase~LTC~BTC',
#    '2~Coinroom~LTC~EUR',
#    '2~BTCE~LTC~EUR',
#    '2~BitMarket~LTC~PLN',
#    '2~BitFlip~LTC~BTC',
#    '2~Coinroom~LTC~GBP',
#    '2~CHBTC~LTC~CNY',
#    '2~WavesDEX~LTC~WAVES',
#    '2~WavesDEX~LTC~USD',
#    '2~WavesDEX~LTC~MRT']},
#  'Message': 'Coin full snapshot successfully returned',
#  'Response': 'Success',
#  'Type': 100}

# %%
imp_data=whole_data['Data']  #EXTRACTING THE DATA FROM WHOLE DATA
imp_data
# Out:
# {'General': {'Algorithm': 'Scrypt',
#   'BaseAngularUrl': '/coins/ltc/',
#   'BlockNumber': 1382821,
#   'BlockReward': 25.0,
#   'BlockRewardReduction': '50%',
#   'BlockTime': 150,
#   'DangerTop': '',
#   'Description': '<p>Litecoin LTC - provides faster transaction confirmations (2.5 minutes on average) and uses a memory-hard, scrypt-based mining proof-of-work algorithm to target the regular computers and GPUs most people already have - which are its main differentials to Bitcoin. The Litecoin network is scheduled to produce 84 million currency units with a halving in reward every four years just like bitcoin. The coin was created by a Google employee, Charles Lee. Litecoin is in second spot to Bitcoin and has spawned numerous clones - however it has a solid base of support and dedicated development team.</p><p><span>The Litecoin project is currently maintained by a core group of 6 software developers, led by Charles Lee, with a large community that is growing in support.</span></p><p>In May 2017, Litecoin became the first of the Top 5 (By Market Cap) cryptocurrencies to implement the\xa0SegWit scaling solution. Later in May of the same year, the first Lightning Network transaction was completed through litecoin, transferring 0.00000001 LTC from Zurich to San Francisco in under one second.</p>',
#   'DifficultyAdjustment': '2016 blocks',
#   'DocumentType': 'Webpagecoinp',
#   'Features': '<p>Litecoin is an open source software project released under the MIT/X11 license which gives you the power to run, modify, and copy the software and to distribute, at your option, modified copies of the software. The software is released in a transparent process that allows for independent verification of binaries and their corresponding source code.</p><p>Miners are currently awarded with 25 new litecoins per block, an amount which gets halved roughly every 4 years (every 840,000 blocks).\xa0The Litecoin network is therefore scheduled to produce 84 million litecoins, which is 4 times as many currency units as Bitcoin.</p><p>The Litecoin blockchain is capable of handling higher transaction volume than its counterpart - Bitcoin. Due to more frequent block generation, the network supports more transactions without a need to modify the software in the future.\xa0As a result, merchants get faster confirmation times, while still having ability to wait for more confirmations when selling bigger ticket items.</p>',
#   'H1Text': 'Litecoin (LTC)',
#   'Id': '3808',
#   'ImageUrl': '/media/19782/litecoin-logo.png',
#   'InfoTop': '',
#   'LastBlockExplorerUpdateTS': 1520702819,
#   'Name': 'Litecoin',
#   'NetHashesPerSecond': 177675622512430.8,
#   'PreviousTotalCoinsMined': 55567917.7471042,
#   'ProofType': 'PoW',
#   '5~CCCAGG~LTC~WGO~4~9080~1516034055~0.01~90.8~dCor3cJBvTcoAAXuKhb7RvZ1amc1oir9EfJpC89C21o~0~0~0~0~9080~9080~9080~9080~9080~9080~WavesDEX~7ffe9',
#   '5~CCCAGG~LTC~MRT~4~0.53~1516841234~0.09573958~0.050741977400000006~ncCERUDQFGHn6XCJK2iPewbAB5bocnFm1VuT7NRAN7W~0~0~0~0~0.53~0.53~0.53~0.53~0.53~0.53~WavesDEX~7ffe9'],
#  'Subs': ['2~BitBay~LTC~EUR',
#   '2~Cexio~LTC~USD',
#   '2~BitGrail~LTC~XRB',
#   '2~WavesDEX~LTC~BTC',
#   '2~Cryptopia~LTC~USDT',
#   '2~LiveCoin~LTC~USD',
#   '2~Cryptopia~LTC~BTC',
#   '2~BTCE~LTC~USD',
#   '2~CCEX~LTC~BTC',
#   '2~BXinth~LTC~THB',
#   '2~BitTrex~LTC~BTC',
#   '2~Poloniex~LTC~XMR',
#   '2~TradeSatoshi~LTC~USDT',
#   '2~Cryptsy~LTC~XRP',
#   '2~BitZ~LTC~BTC',
#   '2~CCEX~LTC~DOGE',
#   '2~Yobit~LTC~DOGE',
#   '2~Binance~LTC~USDT',
#   '2~BitSquare~LTC~BTC',
#   '2~BXinth~LTC~BTC',
#   '2~BTC38~LTC~BTC',
#   '2~Kraken~LTC~USD',
#   '2~Bitstamp~LTC~BTC',
#   '2~WavesDEX~LTC~WGR',
#   '2~Cexio~LTC~BTC',
#   '2~Cryptopia~LTC~NZDT',
#   '2~WavesDEX~LTC~OCL',
#   '2~Bitstamp~LTC~USD',
#   '2~WavesDEX~LTC~EOT',
#   '2~Bitfinex~LTC~USD',
#   '2~Poloniex~LTC~BTC',
#   '2~WavesDEX~LTC~ZEC',
#   '2~Tidex~LTC~WUSD',
#   '2~BitTrex~LTC~USD',
#   '2~Abucoins~LTC~BTC',
#   '2~WavesDEX~LTC~ETH',
#   '2~BitFlip~LTC~RUB',
#   '2~BitSquare~LTC~DASH',
#   '2~Exmo~LTC~RUB',
#   '2~BitFlip~LTC~USD',
#   '2~WavesDEX~LTC~BCH',
#   '2~TrustDEX~LTC~BTC',
#   '2~LiveCoin~LTC~BTC',
#   '2~WavesDEX~LTC~RBX',
#   '2~Kraken~LTC~BTC',
#   '2~BitMarket~LTC~BTC',
#   '2~BitGrail~LTC~BTC',
#   '2~Jubi~LTC~CNY',
#   '2~OKEX~LTC~BTC',
#   '2~Cryptsy~LTC~BTC',
#   '2~Coinse~LTC~BTC',
#   '2~Coinbase~LTC~EUR',
#   '2~Bleutrade~LTC~DOGE',
#   '2~Gateio~LTC~BTC',
#   '2~CCEDK~LTC~DKK',
#   '2~Coinone~LTC~KRW',
#   '2~Gatecoin~LTC~EUR',
#   '2~WavesDEX~LTC~WNET',
#   '2~WavesDEX~LTC~WDESK',
#   '2~CryptoX~LTC~BTC',
#   '2~BitBay~LTC~PLN',
#   '2~Bleutrade~LTC~BTC',
#   '2~BTCE~LTC~CNH',
#   '2~WavesDEX~LTC~WTRY',
#   '2~Coinroom~LTC~PLN',
#   '2~TheRockTrading~LTC~BTC',
#   '2~WavesDEX~LTC~P2P',
#   '2~Cryptopia~LTC~ETH',
#   '2~Exmo~LTC~EUR',
#   '2~WavesDEX~LTC~WCASH',
#   '2~OKEX~LTC~USDT',
#   '2~Yobit~LTC~WAVES',
#   '2~Bleutrade~LTC~ETH',
#   '2~BTER~LTC~CNY',
#   '2~Bitso~LTC~MXN',
#   '2~Gatecoin~LTC~ETH',
#   '2~WavesDEX~LTC~EUR',
#   '2~TradeSatoshi~LTC~BCH',
#   '2~TrustDEX~LTC~AIC',
#   '2~TrustDEX~LTC~USDT',
#   '2~Yacuna~LTC~EUR',
#   '2~TrustDEX~LTC~VND',
#   '2~WavesDEX~LTC~SXAS',
#   '2~BitSquare~LTC~EUR',
#   '2~QuadrigaCX~LTC~BTC',
#   '2~Bitso~LTC~BTC',
#   '2~WavesDEX~LTC~WCT',
#   '2~CCEDK~LTC~EUR',
#   '2~Exmo~LTC~USD',
#   '2~Yacuna~LTC~BTC',
#   '2~OKCoin~LTC~CNY',
#   '2~HitBTC~LTC~EUR',
#   '2~BitFlip~LTC~EUR',
#   '2~BTCChina~LTC~CNY',
#   '2~Yobit~LTC~RUR',
#   '2~TradeSatoshi~LTC~BTC',
#   '2~Binance~LTC~BNB',
#   '2~Kucoin~LTC~USDT',
#   '2~WavesDEX~LTC~AKCHE',
#   '2~CCEDK~LTC~USD',
#   '2~Novaexchange~LTC~BTC',
#   '2~HuobiPro~LTC~USDT',
#   '2~Yobit~LTC~ETH',
#   '2~EXX~LTC~USDT',
#   '2~Huobi~LTC~CNY',
#   '2~QuadrigaCX~LTC~CAD',
#   '2~HitBTC~LTC~BTC',
#   '2~MercadoBitcoin~LTC~BRL',
#   '2~Liqui~LTC~USDT',
#   '2~BTCE~LTC~GBP',
#   '2~BTCE~LTC~BTC',
#   '2~BTCChina~LTC~BTC',
#   '2~Poloniex~LTC~USD',
#   '2~Gatecoin~LTC~BTC',
#   '2~Liqui~LTC~ETH',
#   '2~BitBay~LTC~BTC',
#   '2~OKEX~LTC~BCH',
#   '2~Tidex~LTC~WAVES',
#   '2~OKEX~LTC~ETH',
#   '2~Tidex~LTC~BTC',
#   '2~Bit2C~LTC~BTC',
#   '2~Liqui~LTC~BTC',
#   '2~BitBay~LTC~USD',
#   '2~EXX~LTC~BTC',
#   '2~HitBTC~LTC~ETH',
#   '2~BTCMarkets~LTC~BTC',
#   '2~Kucoin~LTC~NEO',
#   '2~WavesDEX~LTC~TKS',
#   '2~TheRockTrading~LTC~USD',
#   '2~OKCoin~LTC~USD',
#   '2~TradeSatoshi~LTC~DOGE',
#   '2~BTC38~LTC~CNY',
#   '2~WavesDEX~LTC~OCTANOX',
#   '2~WavesDEX~LTC~LIQUID',
#   '2~BitFlip~LTC~UAH',
#   '2~Gateio~LTC~USDT',
#   '2~Kucoin~LTC~ETH',
#   '2~Novaexchange~LTC~ETH',
#   '2~CCEDK~LTC~BTC',
#   '2~WavesDEX~LTC~B@',
#   '2~BTCMarkets~LTC~AUD',
#   '2~TuxExchange~LTC~BTC',
#   '2~Coinbase~LTC~USD',
#   '2~Coinroom~LTC~USD',
#   '2~WavesDEX~LTC~EQUA',
#   '2~Yobit~LTC~USD',
#   '2~CCEX~LTC~USD',
#   '2~HitBTC~LTC~USD',
#   '2~CCEDK~LTC~GBP',
#   '2~Yobit~LTC~BTC',
#   '2~Binance~LTC~ETH',
#   '2~HuobiPro~LTC~BTC',
#   '2~BitTrex~LTC~ETH',
#   '2~Exmo~LTC~BTC',
#   '2~Gatecoin~LTC~HKD',
#   '2~Gatecoin~LTC~USD',
#   '2~Cryptsy~LTC~USD',
#   '2~CCEX~LTC~ETH',
#   '2~Bitstamp~LTC~EUR',
#   '2~Bit2C~LTC~ILS',
#   '2~Bitfinex~LTC~BTC',
#   '2~Tidex~LTC~WEUR',
#   '2~LakeBTC~LTC~BTC',
#   '2~Kucoin~LTC~BTC',
#   '2~Cexio~LTC~EUR',
#   '2~WavesDEX~LTC~WGO',
#   '2~Kraken~LTC~EUR',
#   '2~BTER~LTC~BTC',
#   '2~Binance~LTC~BTC',
#   '2~Bithumb~LTC~KRW',
#   '2~BTCE~LTC~RUB',
#   '2~Tidex~LTC~ETH',
#   '2~TheRockTrading~LTC~EUR',
#   '2~Tidex~LTC~USDT',
#   '2~Coinbase~LTC~BTC',
#   '2~Coinroom~LTC~EUR',
#   '2~BTCE~LTC~EUR',
#   '2~BitMarket~LTC~PLN',
#   '2~BitFlip~LTC~BTC',
#   '2~Coinroom~LTC~GBP',
#   '2~CHBTC~LTC~CNY',
#   '2~WavesDEX~LTC~WAVES',
#   '2~WavesDEX~LTC~USD',
#   '2~WavesDEX~LTC~MRT']}

# %%
coin_list=pd.DataFrame(imp_data)  #MAKING DATA FRAME OF IMP DATA AND THEN
coin_list                                      #TAKING TRANSPOSE TO GET HEADINGS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-22b31d6e1686> in <module>()
# ----> 1 coin_list=pd.DataFrame(imp_data)  #MAKING DATA FRAME OF IMP DATA AND THEN
#       2 coin_list                                      #TAKING TRANSPOSE TO GET HEADINGS
#
# c:\users\khawaja_osama\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# c:\users\khawaja_osama\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# c:\users\khawaja_osama\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# c:\users\khawaja_osama\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
pd.to_csv('coinlist.csv')     #converting the dataframe to excel (csv) and saving it with name coinlist.csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-bd811939dbc8> in <module>()
# ----> 1 pd.to_csv('coinlist.csv')     #converting the dataframe to excel (csv) and saving it with name coinlist.csv
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
coin_list['Id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e394e8f3220f> in <module>()
# ----> 1 coin_list['Id']
#
# NameError: name 'coin_list' is not defined
